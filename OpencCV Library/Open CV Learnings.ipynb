# %% [markdown]
# # Computer Vision with OpenCv library
# - Image processing

# %%
#Install open-cv
# !pip install opencv-python

# %%
# !pip install opencv-python

# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading and Displaying Images

# %%
img=cv2.imread('./images/greenwood.jpg')

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img.shape
# Out:
# (653, 980, 3)

# %%
img
# Out:
# array([[[ 13,  19,  30],
#         [ 10,  16,  27],
#         [  8,  13,  22],
#         ...,
#         [  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2]],
#
#        [[ 15,  21,  32],
#         [ 12,  18,  29],
#         [ 10,  15,  24],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[ 15,  24,  34],
#         [ 12,  21,  31],
#         [ 10,  17,  26],
#         ...,
#         [  2,   4,   4],
#         [  3,   5,   5],
#         [  3,   5,   5]],
#
#        ...,
#
#        [[ 49,  25,   5],
#         [ 47,  23,   3],
#         [ 49,  25,   5],
#         ...,
#         [106, 112, 189],
#         [105, 111, 188],
#         [105, 111, 188]],
#
#        [[ 48,  24,   4],
#         [ 47,  23,   3],
#         [ 49,  25,   5],
#         ...,
#         [105, 111, 188],
#         [105, 111, 188],
#         [104, 110, 187]],
#
#        [[ 46,  25,   4],
#         [ 46,  25,   4],
#         [ 48,  27,   6],
# ...

# %%
img1=plt.imread('./images/greenwood.jpg')

# %%
img1
# Out:
# array([[[ 30,  20,  11],
#         [ 26,  17,  10],
#         [ 22,  13,   6],
#         ...,
#         [  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2]],
#
#        [[ 32,  22,  13],
#         [ 29,  18,  12],
#         [ 24,  15,   8],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[ 34,  24,  15],
#         [ 31,  20,  14],
#         [ 26,  17,  10],
#         ...,
#         [  4,   4,   2],
#         [  5,   5,   3],
#         [  5,   5,   3]],
#
#        ...,
#
#        [[  5,  25,  49],
#         [  3,  23,  47],
#         [  5,  25,  49],
#         ...,
#         [189, 112, 106],
#         [188, 111, 105],
#         [188, 111, 105]],
#
#        [[  4,  24,  48],
#         [  3,  23,  47],
#         [  5,  25,  49],
#         ...,
#         [188, 111, 105],
#         [188, 111, 105],
#         [187, 110, 104]],
#
#        [[  4,  25,  46],
#         [  4,  25,  46],
#         [  6,  27,  48],
# ...

# %%
# %matplotlib
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# # Displaying Image using open cv

# %%
cv2.imshow("Displaying GreenWood",img)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
plt.show()

# %%
dim=img.shape

# %%
rows, cols=dim[:2]

# %%
rows, cols
# Out:
# (653, 980)

# %% [markdown]
# # Get Video from Camera using opencv

# %%
import cv2

# %%
camera=cv2.VideoCapture(0)

# %%
while True:
    rt, frame= camera.read()
    if rt==True:
        cv2.imshow("My video capture", frame)
        key_pressed=cv2.waitKey(1) & 0xFF
        if key_pressed==ord('q') or key_pressed==ord('Q'): # This line will quit loop if q or Q is pressed. Carefully
            break
    else:
        continue
        
camera.release()
cv2.destroyAllWindows()
