# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1=plt.imread('./images/img1.jpg')
img2=plt.imread('./images/img2.jpg')
img3=plt.imread('./images/img3.jpg')
img4=plt.imread('./images/img4.jpg')
img5=plt.imread('./images/img5.jpeg')

# %%
plt.imshow(img1)

# %%
img1=cv2.resize(img1,(200,200))
img2=cv2.resize(img2,(200,200))
img3=cv2.resize(img3,(200,200))
img4=cv2.resize(img4,(200,200))
img5=cv2.resize(img5,(100,100))

# %%
# create another bigger Image to contain all images
full_image=np.zeros((430,430,3), dtype='uint8')

# %%
plt.imshow(img1)

# %%
full_image.shape
# Out:
# (430, 430, 3)

# %%
full_image[10:210,10:210,:]=img1

# %%
full_image[220:420,10:210,:]=img3
full_image[220:420,220:420,:]=img4
full_image[10:210,220:420,:]=img2
x,y=(430//2,430//2)
startW=x-(50+10)
endW=startW+120
startH=y-60
endH=startH+120

# %%
center_img=np.zeros((120,120,3), dtype='uint8')

# %%
center_img[10:10+100,10:10+100]=img5

# %%
plt.imshow(center_img)

# %%
full_image[startH:endH,startW:endW,:]=center_img

# %%
plt.imshow(full_image)

# %%
full_image.shape
# Out:
# (430, 430, 3)

# %%
plt.imsave("./images/processedimg.jpg", full_image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-f76209823029> in <module>
# ----> 1 plt.imsave("./images/processedimg.jpg", full_image)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imsave(fname, arr, **kwargs)
#    2249 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2250 def imsave(fname, arr, **kwargs):
# -> 2251     return matplotlib.image.imsave(fname, arr, **kwargs)
#    2252
#    2253
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1569             rgba = arr
#    1570         else:
# -> 1571             rgba = sm.to_rgba(arr, bytes=True)
#    1572         if pil_kwargs is None:
#    1573             pil_kwargs = {}
#
# ...
