# %% [markdown]
# # Images
# - First thing to know is that Images are stored in form of matrices

# %%
import matplotlib.pyplot as plt

# %%
img=plt.imread('./j1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img.shape
# Out:
# (4032, 3024, 3)

# %%
plt.imshow(img)
plt.axis('on')
plt.show()

# %% [markdown]
# # Croping an Image

# %%
img1=img[600:2500,500:2200,:]

# %%
plt.imshow(img1)
plt.axis('off')
plt.show()
