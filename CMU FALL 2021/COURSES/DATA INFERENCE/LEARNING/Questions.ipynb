# %%
import matplotlib.pyplot as p
import numpy as np
import pandas as pd

# %%
marks=[73,75,74,77]
years=['one','two','three','four']
p.plot(years,marks, marker='x')
p.xlabel('Years', color='blue')
p.ylabel('Marks', color='blue')
p.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
data=pd.read_excel('./ebola_download.xls')

# %%
data
# Out:
#          Date  Cases  Death   Diff  Noofdays
# 0  2014-03-22     49     29      2         1
# 1  2014-03-24     86     59      1         3
# 2  2014-03-25     86     60      1         4
# 3  2014-03-26     86     62      1         5
# 4  2014-03-27    111     72      1         6
# ..        ...    ...    ...    ...       ...
# 75 2014-11-02  13014   5191      2       226
# 76 2014-11-04  13200   5275      5       228
# 77 2014-11-09  14068   5496      2       233
# 78 2014-11-11  14383   5492      1       235
# 79 2014-11-12  14413   5498 -41955       236
#
# [80 rows x 5 columns]

# %%
data.interpolate()
data
# Out:
#          Date  Cases  Death   Diff  Noofdays
# 0  2014-03-22     49     29      2         1
# 1  2014-03-24     86     59      1         3
# 2  2014-03-25     86     60      1         4
# 3  2014-03-26     86     62      1         5
# 4  2014-03-27    111     72      1         6
# ..        ...    ...    ...    ...       ...
# 75 2014-11-02  13014   5191      2       226
# 76 2014-11-04  13200   5275      5       228
# 77 2014-11-09  14068   5496      2       233
# 78 2014-11-11  14383   5492      1       235
# 79 2014-11-12  14413   5498 -41955       236
#
# [80 rows x 5 columns]

# %%
idx=pd.date_range(min(data.Date), max(data.Date))

# %%
data=data.set_index('Date').reindex(idx)

# %%
data2=data.interpolate(method='linear', axis=0,)

# %%
data2.columns=['Cases','Death','Diff','Noofdays']

# %%
above100=data[(data['Cases']>=100) & (data['Death']>=100)]
above100
# Out:
#               Cases   Death     Diff  Noofdays
# 2014-04-07    172.0   105.0      2.0      17.0
# 2014-04-09    179.0   111.0      1.0      19.0
# 2014-04-10    183.0   113.0      1.0      20.0
# 2014-04-11    184.0   114.0      3.0      21.0
# 2014-04-14    194.0   121.0      2.0      24.0
# ...             ...     ...      ...       ...
# 2014-11-02  13014.0  5191.0      2.0     226.0
# 2014-11-04  13200.0  5275.0      5.0     228.0
# 2014-11-09  14068.0  5496.0      2.0     233.0
# 2014-11-11  14383.0  5492.0      1.0     235.0
# 2014-11-12  14413.0  5498.0 -41955.0     236.0
#
# [71 rows x 4 columns]

# %%
above100
# Out:
#               Cases   Death     Diff  Noofdays
# 2014-04-07    172.0   105.0      2.0      17.0
# 2014-04-09    179.0   111.0      1.0      19.0
# 2014-04-10    183.0   113.0      1.0      20.0
# 2014-04-11    184.0   114.0      3.0      21.0
# 2014-04-14    194.0   121.0      2.0      24.0
# ...             ...     ...      ...       ...
# 2014-11-02  13014.0  5191.0      2.0     226.0
# 2014-11-04  13200.0  5275.0      5.0     228.0
# 2014-11-09  14068.0  5496.0      2.0     233.0
# 2014-11-11  14383.0  5492.0      1.0     235.0
# 2014-11-12  14413.0  5498.0 -41955.0     236.0
#
# [71 rows x 4 columns]

# %%
data2
# Out:
#               Cases   Death     Diff  Noofdays
# 2014-03-22     49.0    29.0      2.0       1.0
# 2014-03-23     67.5    44.0      1.5       2.0
# 2014-03-24     86.0    59.0      1.0       3.0
# 2014-03-25     86.0    60.0      1.0       4.0
# 2014-03-26     86.0    62.0      1.0       5.0
# ...             ...     ...      ...       ...
# 2014-11-08  13894.4  5451.8      2.6     232.0
# 2014-11-09  14068.0  5496.0      2.0     233.0
# 2014-11-10  14225.5  5494.0      1.5     234.0
# 2014-11-11  14383.0  5492.0      1.0     235.0
# 2014-11-12  14413.0  5498.0 -41955.0     236.0
#
# [236 rows x 4 columns]

# %%
data2
# Out:
#               Cases   Death     Diff  Noofdays
# 2014-03-22     49.0    29.0      2.0       1.0
# 2014-03-23     67.5    44.0      1.5       2.0
# 2014-03-24     86.0    59.0      1.0       3.0
# 2014-03-25     86.0    60.0      1.0       4.0
# 2014-03-26     86.0    62.0      1.0       5.0
# ...             ...     ...      ...       ...
# 2014-11-08  13894.4  5451.8      2.6     232.0
# 2014-11-09  14068.0  5496.0      2.0     233.0
# 2014-11-10  14225.5  5494.0      1.5     234.0
# 2014-11-11  14383.0  5492.0      1.0     235.0
# 2014-11-12  14413.0  5498.0 -41955.0     236.0
#
# [236 rows x 4 columns]

# %%
above100.iloc[:1][:3]['Cases'].index[0]
# Out:
# Timestamp('2014-04-07 00:00:00')

# %%
a=str(above100.index[0])

# %%
a[:-9]
# Out:
# '2014-04-07'
